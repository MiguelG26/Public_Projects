# %% [markdown]
# <a href="https://colab.research.google.com/github/MiguelG26/Learning/blob/master/Hands-On%20Machine%20Learning%20with%20Scikit-Learn%20and%20TensorFlow2/09_unsupervised_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Chapter 9 – Unsupervised Learning**
#
# _This notebook contains all the sample code in chapter 9._

# %% [markdown]
# <table align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/github/ageron/handson-ml2/blob/master/09_unsupervised_learning.ipynb"><img src="https://www.tensorflow.org/images/colab_logo_32px.png" />Run in Google Colab</a>
#   </td>
# </table>

# %% [markdown]
# # Setup

# %% [markdown]
# First, let's import a few common modules, ensure MatplotLib plots figures inline and prepare a function to save the figures. We also check that Python 3.5 or later is installed (although Python 2.x may work, it is deprecated so we strongly recommend you use Python 3 instead), as well as Scikit-Learn ≥0.20.

# %%
# Common imports
import os
import urllib
import numpy as np
#from sklearn.datasets import load_iris
from sklearn.cluster import KMeans
from matplotlib.image import imread
from sklearn.preprocessing import MinMaxScaler
#from tensorflow.keras.preprocessing import image
from skimage.transform import resize

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

# Where to save the figures
PROJECT_ROOT_DIR = "."
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images")
os.makedirs(IMAGES_PATH, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="jpg", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %%
conda list
# Out:
# # packages in environment at C:\Users\GarciaM\Anaconda3\envs\dashfaro:
# #
# # Name                    Version                   Build  Channel
# aiohttp                   3.6.2                    pypi_0    pypi
# alabaster                 0.7.12                   pypi_0    pypi
# ansi2html                 1.5.2                    pypi_0    pypi
# async-timeout             3.0.1                    pypi_0    pypi
# atomicwrites              1.4.0                    pypi_0    pypi
# attrs                     19.3.0                   pypi_0    pypi
# babel                     2.8.0                    pypi_0    pypi
# backcall                  0.2.0                    pypi_0    pypi
# beautifulsoup4            4.9.1                    pypi_0    pypi
# blas                      1.0                         mkl
# bleach                    3.1.5                    pypi_0    pypi
# brotli                    1.0.7                    pypi_0    pypi
# ca-certificates           2020.6.24                     0
# certifi                   2020.4.5.1               pypi_0    pypi
# cffi                      1.14.0                   pypi_0    pypi
# chardet                   3.0.4                    pypi_0    pypi
# chart-studio              1.1.0                    pypi_0    pypi
# click                     6.7                      pypi_0    pypi
# colorama                  0.4.3                    pypi_0    pypi
# colorlover                0.3.0                    pypi_0    pypi
# cryptography              2.9.2                    pypi_0    pypi
# cufflinks                 0.17.3                   pypi_0    pypi
# cycler                    0.10.0                   pypi_0    pypi
# dash                      1.13.4                   pypi_0    pypi
# dash-auth                 1.4.1                    pypi_0    pypi
# dash-bootstrap-components 0.11.1                   pypi_0    pypi
# dash-core-components      1.10.1                   pypi_0    pypi
# dash-html-components      1.0.3                    pypi_0    pypi
# dash-renderer             1.5.1                    pypi_0    pypi
# dash-table                4.8.1                    pypi_0    pypi
#
# Note: you may need to restart the kernel to use updated packages.decorator                 4.4.2                    pypi_0    pypi
#
# defusedxml                0.6.0                    pypi_0    pypi
# docutils                  0.16                     pypi_0    pypi
# entrypoints               0.3                      pypi_0    pypi
# et-xmlfile                1.1.0                    pypi_0    pypi
# flask                     1.1.2                    pypi_0    pypi
# flask-compress            1.5.0                    pypi_0    pypi
# flask-seasurf             0.3.0                    pypi_0    pypi
# freetype                  2.10.2               hd328e21_0
# future                    0.18.2                   pypi_0    pypi
# gunicorn                  20.0.4                   pypi_0    pypi
# icc_rt                    2019.0.0             h0cc432a_1
# icu                       58.2                 ha925a31_3
# idna                      2.10                     pypi_0    pypi
# imageio                   2.16.1                   pypi_0    pypi
# imagesize                 1.2.0                    pypi_0    pypi
# importlib-metadata        1.7.0                    pypi_0    pypi
# intel-openmp              2020.1                      216
# ipykernel                 5.3.2                    pypi_0    pypi
# ipython                   7.16.1                   pypi_0    pypi
# ipython-genutils          0.2.0                    pypi_0    pypi
# ipywidgets                7.5.1                    pypi_0    pypi
# itsdangerous              1.1.0                    pypi_0    pypi
# jedi                      0.17.1                   pypi_0    pypi
# jinja2                    2.11.2                   pypi_0    pypi
# joblib                    0.16.0                   pypi_0    pypi
# jpeg                      9b                   hb83a4c4_2
# jsonschema                3.2.0                    pypi_0    pypi
# jupyter-client            6.1.5                    pypi_0    pypi
# jupyter-core              4.6.3                    pypi_0    pypi
# jupyter-dash              0.2.1.post1              pypi_0    pypi
# jupyter-server-proxy      1.5.0                    pypi_0    pypi
# kiwisolver                1.2.0            py37h74a9793_0
# libpng                    1.6.37               h2a8f88b_0
# markupsafe                1.1.1                    pypi_0    pypi
# matplotlib                3.2.2                         0
# matplotlib-base           3.2.2            py37h64f37c6_0
# mistune                   0.8.4                    pypi_0    pypi
# mkl                       2020.1                      216
# mkl-service               2.3.0            py37hb782905_0
# mkl_fft                   1.1.0            py37h45dec08_0
# mkl_random                1.1.1            py37h47e9c7a_0
# multidict                 4.7.6                    pypi_0    pypi
# nbconvert                 5.6.1                    pypi_0    pypi
# nbformat                  5.0.7                    pypi_0    pypi
# networkx                  2.6.3                    pypi_0    pypi
# notebook                  6.0.3                    pypi_0    pypi
# numpy                     1.19.0                   pypi_0    pypi
# numpy-base                1.18.5           py37hc3f5095_0
# openpyxl                  3.0.7                    pypi_0    pypi
# openssl                   1.1.1g               he774522_0
# packaging                 20.4                     pypi_0    pypi
# pandas                    1.0.5            py37h47e9c7a_0
# pandocfilters             1.4.2                    pypi_0    pypi
# parso                     0.7.0                    pypi_0    pypi
# patsy                     0.5.1                    pypi_0    pypi
# pickleshare               0.7.5                    pypi_0    pypi
# pillow                    9.0.1                    pypi_0    pypi
# pip                       20.1.1                   py37_1
# plotly                    4.8.2                    pypi_0    pypi
# prometheus-client         0.8.0                    pypi_0    pypi
# prompt-toolkit            3.0.5                    pypi_0    pypi
# pycovid                   1.0.0                    pypi_0    pypi
# pycparser                 2.20                     pypi_0    pypi
# pygments                  2.6.1                    pypi_0    pypi
# pyparsing                 2.4.7                      py_0
# pyqt                      5.9.2            py37h6538335_2
# pyrsistent                0.16.0                   pypi_0    pypi
# python                    3.7.7                h81c818b_4
# python-dateutil           2.8.1                      py_0
# pytz                      2020.1                     py_0
# pywavelets                1.2.0                    pypi_0    pypi
# pywin32                   228                      pypi_0    pypi
# pywinpty                  0.5.7                    pypi_0    pypi
# pyzmq                     19.0.1                   pypi_0    pypi
# qt                        5.9.7            vc14h73c81de_0
# requests                  2.24.0                   pypi_0    pypi
# retrying                  1.3.3                    pypi_0    pypi
# scikit-image              0.19.2                   pypi_0    pypi
# scikit-learn              1.0.2                    pypi_0    pypi
# scipy                     1.5.1                    pypi_0    pypi
# seaborn                   0.10.1                     py_0
# send2trash                1.5.0                    pypi_0    pypi
# setuptools                47.3.1                   py37_0
# simpervisor               0.3                      pypi_0    pypi
# sip                       4.19.8           py37h6538335_0
# six                       1.15.0                     py_0
# sklearn                   0.0                      pypi_0    pypi
# snowballstemmer           2.0.0                    pypi_0    pypi
# soupsieve                 2.0.1                    pypi_0    pypi
# sphinx                    3.1.2                    pypi_0    pypi
# sphinx-gallery            0.7.0                    pypi_0    pypi
# sphinxcontrib-applehelp   1.0.2                    pypi_0    pypi
# sphinxcontrib-devhelp     1.0.2                    pypi_0    pypi
# sphinxcontrib-htmlhelp    1.0.3                    pypi_0    pypi
# sphinxcontrib-jsmath      1.0.1                    pypi_0    pypi
# sphinxcontrib-qthelp      1.0.3                    pypi_0    pypi
# sphinxcontrib-serializinghtml 1.1.4                    pypi_0    pypi
# sqlite                    3.32.3               h2a8f88b_0
# statsmodels               0.11.1                   pypi_0    pypi
# terminado                 0.8.3                    pypi_0    pypi
# testpath                  0.4.4                    pypi_0    pypi
# threadpoolctl             3.1.0                    pypi_0    pypi
# tifffile                  2021.11.2                pypi_0    pypi
# tornado                   6.0.4            py37he774522_1
# traitlets                 4.3.3                    pypi_0    pypi
# ua-parser                 0.10.0                   pypi_0    pypi
# urllib3                   1.25.9                   pypi_0    pypi
# vc                        14.1                 h0510ff6_4
# vs2015_runtime            14.16.27012          hf0eaf9b_3
# wcwidth                   0.2.5                    pypi_0    pypi
# webencodings              0.5.1                    pypi_0    pypi
# werkzeug                  1.0.1                    pypi_0    pypi
# wheel                     0.34.2                   py37_0
# widgetsnbextension        3.5.1                    pypi_0    pypi
# wincertstore              0.2                      py37_0
# xlrd                      1.2.0                    py37_0
# xlsxwriter                3.0.1                    pypi_0    pypi
# yarl                      1.4.2                    pypi_0    pypi
# zipp                      3.1.0                    pypi_0    pypi
# zlib                      1.2.11               h62dcd97_4

# %% [markdown]
# ### Using clustering for image segmentation

# %%
link="https://raw.githubusercontent.com/ageron/handson-ml2/master/images/unsupervised_learning/ladybug.png"
filename = link[link.rfind("/")+1:]
urllib.request.urlretrieve(link, os.path.join(IMAGES_PATH, filename))
# Out:
# ('.\\images\\ladybug.png', <http.client.HTTPMessage at 0x274fd1b16c8>)

# %%
link="https://raw.githubusercontent.com/MiguelG26/Learning/master/handson-ml2/images/unsupervised_learning/ando.jpg"
filename = link[link.rfind("/")+1:]
urllib.request.urlretrieve(link, os.path.join(IMAGES_PATH, filename))
# Out:
# ('.\\images\\ando.jpg', <http.client.HTTPMessage at 0x274fd19d4c8>)

# %%
link='https://www.soundandrecording.de/wp-content/uploads/2018/06/Mixpraxis-The-Beatles-RS23_05_Gatefold.jpg'
filename = link[link.rfind("/")+1:]
urllib.request.urlretrieve(link, os.path.join(IMAGES_PATH, filename))
# Out:
# ('.\\images\\Mixpraxis-The-Beatles-RS23_05_Gatefold.jpg',
#  <http.client.HTTPMessage at 0x274f91188c8>)

# %%
scaler = MinMaxScaler()
#to upload the image as np.array to get its height & lenght
image0=IMAGES_PATH+"/Elia3.jpg" #for local images
#my_image0 = imread(os.path.join(IMAGES_PATH, filename)) #for internet images

#my_image0 = imread(os.path.join(IMAGES_PATH, filename)) #for internet images

height=400
divider=my_image0.shape[0]/height
lenght=int(round(my_image0.shape[1]/divider,0))

#resize image
my_image = resize(my_image0, (400, lenght))

#to reshape the image from 3D to 2D & to scale values between 0 & 1
X = my_image.reshape(-1, 3)
X = scaler.fit_transform(X.astype(np.float64))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-6f86457ed725> in <module>
#       5
#       6 height=400
# ----> 7 divider=my_image0.shape[0]/height
#       8 lenght=int(round(my_image0.shape[1]/divider,0))
#       9
#
# NameError: name 'my_image0' is not defined

# %%
segmented_imgs = []
n_colors = (3, 2)
for n_clusters in n_colors:
    kmeans = KMeans(n_clusters=n_clusters, random_state=42).fit(X) #train kmeans
    segmented_img = kmeans.cluster_centers_[kmeans.labels_] #to segment the images
    segmented_imgs.append(segmented_img.reshape(my_image.shape)) #to append segmented images to the list of images & reshape the image from 2D back to to 3D

plt.figure(figsize=(20,10))
plt.subplots_adjust(wspace=0.05, hspace=0.1)

plt.subplot(231)
plt.imshow(my_image)
plt.title("Original image")
plt.axis('off')

for idx, n_clusters in enumerate(n_colors):
    plt.subplot(232 + idx)
    plt.imshow(segmented_imgs[idx])
    plt.title("{} colors".format(n_clusters))
    plt.axis('off')
#to save the image as .png
save_fig('image_segmentation_diagram', tight_layout=False)
plt.show()
# Out:
# Saving figure image_segmentation_diagram

# %%
fig = imread(os.path.join(IMAGES_PATH, 'image_segmentation_diagram.png'))
#fig = image.load_img(os.path.join(images_path, 'image_segmentation_diagram.png'))
fig = plt.imshow(fig)
type(fig)

# %%
from matplotlib.figure import Figure
import random

fig = Figure()
axis = fig.add_subplot(1, 1, 1)
xs = range(100)
ys = [random.randint(1, 50) for x in xs]
axis.plot(xs, ys)
type(fig)

# %%
import io
import random
from flask import Response
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
from matplotlib.figure import Figure

def create_figure():
    fig = Figure()
    axis = fig.add_subplot(1, 1, 1)
    xs = range(100)
    ys = [random.randint(1, 50) for x in xs]
    axis.plot(xs, ys)

    return fig

fig = create_figure()
output = io.BytesIO()
FigureCanvas(fig).print_png(output)
Response(output.getvalue(), mimetype='image/png')

# %%
type(Response(output.getvalue(), mimetype='image/png'))
